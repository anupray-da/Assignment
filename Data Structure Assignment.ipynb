# %% [markdown]
# #Data Types and Structures Questions
# 1. What are data structures, and why are they important?
#  - Data structures are specialized formats for organizing, storing, and accessing collections of data.
#  - They are important because choosing the right data structure significantly impacts the efficiency and performance of your program. Also it simplifies data manipulation.
#  -It helps on optimizing storing and sorting operations and conserve memory usage.
#
# 2.  Explain the difference between mutable and immutable data types with examples.
#  - Mutable data types are objects whose elements can be changed after they got created.
#  -Where data is not fixed and can be changed after in that place we use mutable objects.
#  - Ex.- List, dictionary, set
#  - Please refer below example.

# %%
a=[1,2,3]
a.append(4)
a
# Out:
# [1, 2, 3, 4]

# %% [markdown]
#   - Immutable objects are on other hand can not changed once got created.
# - These are used where data should not changed afterwards.
# - Ex.-string, tuple
# - Please refer Below Example.

# %%
b=(1,2,3)
b.append(4)
b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-cf4009e4f731> in <cell line: 2>()
#       1 b=(1,2,3)
# ----> 2 b.append(4)
#       3 b
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# 3. What are the main differences between lists and tuples in Python.
#  - Lists are mutable which means we can modify them after it got created.
#  - It makes them more flexible but it takes more space and much slower than tuples.
#  - Syntax for list is '[]'
#  - Tuples are immutable which means we can not modify it after it's creation. Which prevent any accidental modification and make the code more reliable.
#  -These are generally faster than lists.
#  - Syntax for tuple is '()'
#
# 4. Describe how dictionaries store data.
#  - Dictionaries are unordered collection which means elements are not stored in a specific order.
#  - It store values in key and value pair which means each key acts as a unique identifier for associated value.
#  - It takes very less time to retrive the data.
#  - Ex. dictnr = {1:'a',2:'b'}
#
# 5. Why might you use a set instead of a list in Python?
#  - Set helps to store data and remove the duplicates automatically but list does not remove duplicates.
#  - Sets are useful for checking membership or finding the intersection/difference between sets.
#
# 6.  What is a string in Python, and how is it different from a list?
#  - String is a sequence of characters, such as letters, numbers etc.
#  - Strings are always placed inside single quote or double quotes whereas lists are enclosed in square brackets.
#  - Strings are immutable while list is mutable.
#
# 7. How do tuples ensure data integrity in Python?
#   - Tuples are immutable which means we can not change them after it got created.
#   - Here you cant add or remove anything from tuple.
#   - It prevents ay accidental changes and make the code more reliable.
#
# 8. What is a hash table, and how does it relate to dictionaries in Python?
#  - A hash table is a data structure that stores data in key-value pairs, where each key is unique and maps to a specific value.
#  - Dictionaries in Python are implemented using hash tables. Which makes them so efficient for storing and retrieving data.
#  - Dictionaries store data as key-value pairs like hash table.
#
# 9. Can lists contain different data types in Python?
#  - Yes, in Python lists can contain different type of data types.
#  - We can store int, float,strings and others which make lists more flexible.
#
# 10.  Explain why strings are immutable in Python.
#  - In Python, strings are immutable, meaning their contents cannot be changed after they are created.
#  - Here we can not able to add, delete or modify the strings.
#  - It prevents any accidental update which makes them good to use in code.
#  - For this it is more efficient and takes less storage.
#
# 11. What advantages do dictionaries offer over lists for certain tasks?
#  - Dictionaries store data as key-value pairs, while lists store data as an ordered sequence.
#  - In dictionary we can fetch the values by using key, which makes them more faster for retriving data.
#  - Dictionary keys are unique which makes it more useful for avoiding duplicates and maintaining data integrity.
#
# 12. Describe a scenario where using a tuple would be preferable over a list.
#  - Tuples are immutable whereas list is mutable.
#  - Suppose we are storing emloyee id details where the data should not be changed after it got created, there we need to use tuple.
#  - Also it prevents any accidental modification to the existing data.
#  - This ensures the data intigrity and align with the purpose of data storing.
#
# 13. How do sets handle duplicate values in Python?
#  - In Python sets are designed to store only unique values.
#  - They automatically delete the duplicate data from the sets.
#  - Also if you will add any duplicates it will ignore your input and the set will be unchanged.
#  - Set uses hash table to store the data, if two elements is having same hash code it will ignore one of them.
#
# 14.  How does the “in” keyword work differently for lists and dictionaries?
#  - 'in' keyword is generally used to find the membership.
#  - It checks if a given value is present inside a list or dictionary.
#  - In list we check if the value is present or not.
#  - But in dictionary we check if the key is there or not.
#
# 15. Can you modify the elements of a tuple? Explain why or why not.
#  - No, you can not modify the elements of a tuple.
#  - In Python, it is designed to be immutable which means we can not add, remove or make any kind of changes to the tuple after it got created.
#  - Tuples are used where the data is fixed and should not be changed. Which makes it more efficient and take less storage.
#
# 16. What is a nested dictionary, and give an example of its use case?
# - A nested dictionary is a dictionary where values of the dictionary itself is a dictionary.
# - It is basically dictionary inside a dictionary. which used to store multi layered data.
# - Ex. When a company storing their employee details
# - employee_records = {
#     'E001': {'name': 'John Doe', 'department': 'Engineering', 'salary': 75000},
#     'E002': {'name': 'Jane Smith', 'department': 'Marketing', 'salary': 65000},
#     'E003': {'name': 'David Lee', 'department': 'Finance', 'salary': 80000}
# }
#
# 17. Describe the time complexity of accessing elements in a dictionary.
#  - In Python, dictionary store data using hast table.
#  - Which make them more efficient and give result super fast.
#  - When we pass the key of dictionary we can get the corresponding values associated to it.
#  - On average, accessing an element in a dictionary has a time complexity of
#  O(1)
# 18. In what situations are lists preferred over dictionaries.
#  - When the order of elements are required in that case we use lists over dictionaries.
#  - List also can store duplicate values, so when duplicate value is necessary in that place we use lists.
#  - Also lists are very straightforward, when values don't need any specific organization in that time we can use lists.
#  - When you need to iterate through elements in a specific order, lists are generally more convenient than dictionaries.
#
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
#  - Dictionaries are considered unordered collection of data, which means they don't have any specific order for storing the data.
#  - You cannot access elements in a dictionary using numerical indices like you can with lists. Here you need to use the keys to retrieve the corresponding values to it.
#  - When we need to iterate over dictionary, the output order may not be same to the order they were added.
#
# 20.  Explain the difference between a list and a dictionary in terms of data retrieval.
#  - Lists store values in a sequential order, so we can use the index of value to retrive the data.
#  - In other hand dictionary store data in key and value pair, so we need to pass the keys to retrive its corresponding values.

# %% [markdown]
# #Practical Questions

# %%
# 1)Write a code to create a string with your name and print it
Name='Anup Ray'
Name
# Out:
# 'Anup Ray'

# %%
# 2)Write a code to find the length of the string "Hello World".
ab="Hello World"
len(ab)
# Out:
# 11

# %%
# 3)Write a code to slice the first 3 characters from the string "Python Programming".
a="Python Programming"
a[0:3]
# Out:
# 'Pyt'

# %%
# 4)Write a code to convert the string "hello" to uppercase.
b="hello"
b.upper()
# Out:
# 'HELLO'

# %%
# 5)Write a code to replace the word "apple" with "orange" in the string "I like apple".
c="I like apple"
c.replace("apple","orange")
# Out:
# 'I like orange'

# %%
# 6)Write a code to create a list with numbers 1 to 5 and print it.
for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# 7)Write a code to append the number 10 to the list [1, 2, 3, 4].
d=[1,2,3,4]
d.append(10)
d
# Out:
# [1, 2, 3, 4, 10]

# %%
# 8)Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
e=[1,2,3,4,5]
e.remove(5)
e
# Out:
# [1, 2, 3, 4]

# %%
# 9)Write a code to access the second element in the list ['a', 'b', 'c', 'd'].
f=['a','b','c','d']
f[1]
# Out:
# 'b'

# %%
# 10)Write a code to reverse the list [10, 20, 30, 40, 50]
g=[10,20,30,40,50]
g[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %%
# 11)Write a code to create a tuple with the elements 10, 20, 30 and print it.
h=(10,20,30)
h
# Out:
# (10, 20, 30)

# %%
# 12) Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').
i=('apple','banana','cherry')
i[0]
# Out:
# 'apple'

# %%
# 13) Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).
j=(1,2,3,2,4,2)
j.count(2)
# Out:
# 3

# %%
# 14)Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')
k=('dog','cat','rabbit')
k.index('cat')
# Out:
# 1

# %%
# 15) Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').
l=('apple','orange','banana')
'banana' in l
# Out:
# True

# %%
# 16)Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.
m={1,2,3,4,5}
m
# Out:
# {1, 2, 3, 4, 5}

# %%
# 17) Write a code to add the element 6 to the set {1, 2, 3, 4}
n={1,2,3,4}
n.add(6)
n
# Out:
# {1, 2, 3, 4, 6}

# %%
# 18)Write a code to create a tuple with the elements 10, 20, 30 and print it.
h=(10,20,30)
h
# Out:
# (10, 20, 30)

# %%
# 19) Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').
i=('apple','banana','cherry')
i[0]
# Out:
# 'apple'

# %%
# 20) Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).
j=(1,2,3,2,4,2)
j.count(2)
# Out:
# 3

# %%
# 21)Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')
k=('dog','cat','rabbit')
k.index('cat')
# Out:
# 1

# %%
# 22) Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').
l=('apple','orange','banana')
'banana' in l
# Out:
# True

# %%
# 23)Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.
m={1,2,3,4,5}
m
# Out:
# {1, 2, 3, 4, 5}

# %%
# 24) Write a code to add the element 6 to the set {1, 2, 3, 4}
n={1,2,3,4}
n.add(6)
n
# Out:
# {1, 2, 3, 4, 6}
